# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('trino://root:@trinoserv.bigdata:8090/hive/ais')

# %%
mydf = pd.read_sql("show schemas", con=engine)

# %%
df2 = mydf.to_dict('records')

# %%
mydf2 = pd.read_sql(f"show tables in {mydf}", con=engine)
# Out:
# ---------------------------------------------------------------------------
# TrinoUserError                            Traceback (most recent call last)
# File /HDFS01/anaconda3/envs/main/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1802, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801     if not evt_handled:
# -> 1802         self.dialect.do_execute(
#    1803             cursor, statement, parameters, context
#    1804         )
#    1806 if self._has_events or self.engine._has_events:
#
# File /HDFS01/anaconda3/envs/main/lib/python3.9/site-packages/trino/sqlalchemy/dialect.py:365, in TrinoDialect.do_execute(self, cursor, statement, parameters, context)
#     362 def do_execute(
#     363     self, cursor: Cursor, statement: str, parameters: Tuple[Any, ...], context: DefaultExecutionContext = None
#     364 ):
# --> 365     cursor.execute(statement, parameters)
#
# ...
