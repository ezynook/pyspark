# %%
import pandas as pd

# %%
df = pd.read_json('http://lawsystem.duckdns.org/api_json.php')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Date'] = df['Date'].dt.strftime('%d/%m/%Y')

# %%
df
# Out:
#                                                Subject  \
# 0    "ทนายษิทรา" เผยโทษเอาผิด ชายปริศนาบุกต่อยหน้า ...
# 1    "ทนายษิทรา" เผยโทษเอาผิด ชายปริศนาบุกต่อยหน้า ...
# 2    "ทนายษิทรา" เผยโทษเอาผิด ชายปริศนาบุกต่อยหน้า ...
# 3    "ไอ้คลั่ง" จนมุม ยิงกลางทุ่งนา ตาย 1 เจ็บ 2 ตร...
# 4    2 โจ๋แว้นบ้านผือ ซิ่งจยย. บิดหมอบ-ปิดไฟหน้ารถช...
# ..                                                 ...
# 185  โจรย่องขึ้นบ้าน "แอน ทองประสม" ยกเค้ากวาดทรัพย...
# 186  โจรย่องขึ้นบ้าน "แอน ทองประสม" ยกเค้ากวาดทรัพย...
# 187  ไม่อยู่บ้าน 4 ปี เพื่อนบ้านตัดกุญแจ บุกรุก พ่ว...
# 188  ไรเดอร์เลือดร้อน วางมวยโจทก์เก่า เมาสู้ไม่ได้ ...
# 189  ไรเดอร์เลือดร้อน วางมวยโจทก์เก่า เมาสู้ไม่ได้ ...
#
#                                                 Detail        Date  \
# 0    "ทนายษิทรา" เผยโทษ กรณีคนบุกชกหน้า "ศรีสุวรรณ"...  18/10/2022
# 1    "ทนายษิทรา" เผยโทษ กรณีคนบุกชกหน้า "ศรีสุวรรณ"...  18/10/2022
# 2    "ทนายษิทรา" เผยโทษ กรณีคนบุกชกหน้า "ศรีสุวรรณ"...  18/10/2022
# 3    ผบ.ตร.ส่งชุดปฏิบัติการพิเศษ ภ.จว.ลำปาง บุกจับ ...  10/11/2022
# 4    อุบัติเหตุรถจักรยานยนต์ พุ่งชนรถจักรยานบนถนนบ้...  05/11/2022
# ..                                                 ...         ...
# 185  หัวขโมยย่องขึ้นบ้าน "แอน ทองประสม" นางเอกสาวคน...  30/07/2022
# 186  หัวขโมยย่องขึ้นบ้าน "แอน ทองประสม" นางเอกสาวคน...  30/07/2022
# 187  เจ้าของบ้านเซ็ง ไม่อยู่บ้านนาน 4 ปี กลับมาครั้...  03/03/2021
# 188  หนุ่มไรเดอร์เลือดร้อน เปิดศึกวางมวยช่างเหล็กโจ...  02/09/2022
# 189  หนุ่มไรเดอร์เลือดร้อน เปิดศึกวางมวยช่างเหล็กโจ...  02/09/2022
#
#           Province            Law
# 0    กรุงเทพมหานคร    มาตรา ๒๙๕
# 1    กรุงเทพมหานคร      มาตรา ๒๙๗
# 2    กรุงเทพมหานคร      มาตรา ๓๐๐
# 3            ลำปาง      มาตรา ๒๘๘
# 4         อุดรธานี      มาตรา ๒๘๘
# ..             ...            ...
# 185  กรุงเทพมหานคร  มาตรา ๓๔๐ ตรี
# 186  กรุงเทพมหานคร  มาตรา ๓๔๐ ทวิ
# 187  กรุงเทพมหานคร      มาตรา ๓๖๓
# 188  กรุงเทพมหานคร      มาตรา ๒๘๘
# 189  กรุงเทพมหานคร      มาตรา ๒๙๑
#
# [190 rows x 5 columns]
